# %% [markdown]
# ## Introduction to matplotlib

# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# %%
plt.plot()
plt.show()

# %%
plt.plot([1,2,3,4])
plt.show()

# %%
plt.plot([1,2,3,4], [11,22,33,44])
plt.show()

# %%
x = [1,2,3,4]
y = [11,22,33,44]
plt.plot(x,y)
plt.show()
